# %% [markdown]
#    # Going Bananas with Transfer Learning

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%bash
# cd tensorflow-for-poets-2/tf_files
# pwd
# ls
# Out:
# /gpfs/fs01/user/s37a-6a8375ad9b78b5-6459f7095f24/notebook/work/tensorflow-for-poets-2/tf_files

# %% [markdown]
# ### Acknowledgments:
# * **Tensorflow for Poets** (codelabs.developers.google.com)
# * **Siraj Raval** (Youtube: Build a TensorFlow Image Classifier in 5 Min)
#
# ### Objective
# We are going to use a model trained on the ImageNet Large Visual Recognition Challenge dataset. These models can differentiate between 1,000 different classes, like Dalmatian or dishwasher. It's **NOT** good at classifying flower types. We will start with the generic ImageNet model called **Inception V3** or its smaller cousin **MobileNet** which do not classify flowers. We will use **MobileNet** which is smaller and faster but less accurate than ImageNet. We will use this model as the starting point to re-train a new model which does a good job of classifying flowers.  This technique is called **transfer learning.**
#
# We will use this same model, but retrain it to tell apart a small number of classes based on our own examples.
#
# **What you will learn:**
#
# * How to use Python and TensorFlow to train an image classifier
# * How to classify images with your trained classifier
#
# **What you need:**
# * **A basic understanding of Linux commands**
#
# In the graphic below, we see three states of the deep neural network.  On the left is the pre-trained network before data has been applied to it. The tan box contains a depiction of a neural network as it is being trained. The green network third from the left represents the network, or "the model", after it has been trained.  At the far right is a depiction of how the model is incorporated in a data flow to performance inference in deployment scenarios.
#
# In the graphic, input data is seen as applied at the top of the network, and the output classifications are seen at the bottom (2 outputs shown here).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Transfer learning
# Is allows research teams to develop generic models that do pretty well at a broad class of images. It may take weeks to develop such a model. After it is created it is in the green middle state.
#
# A developer may wish to leverage all the work subsumed within the model but to tweak it in some way to classify specific type of images, or to have a differnet number of classification outputs.  Additionally, the last layer (the bottom layer shown here) needs to be removed and replaced by a new neural layer with the same number of outputs as we now whish to classify.
#
# The python code called by this notebook handles all this for you.
#
# Operationally, a user can download whatever images they wish to train against. Place them into individual folders named accordin to the desired class. This is a supervised learning task. The user finds images that match their class definition and places them into a labeled folder.  Repeat this for as many classes as desired.
#
# When the retrain.py sript is run, it finds the labeled folders, re-trains the network's newly created final layer only.
#
# The implicaitons of this are:
# * re-training takes much less data
# * re-training takes much less time
# * re-training builds on the fundamental buidling blocks established by researchers dedicated to finding and publishing state of the art techniques.
# * re-training works for related types of domains, for example, a general image classifier can be re-trained to specialize in faces, or banana ripeness, or whatever you decide.

# %% [markdown]
# # Let's start the lab
#
#
# # 1) Clone the git repository
# All the code used in this codelab (except the displayImage.py) is contained in this git repository. Clone the repository and cd into it. This is where we will be working. running the cell will download the code, model, scripts needed to run this lab.
#
# ## To save time, run this cell only once!
# Clone the tensorflow-for-poets code from googlecodelabs github

# %%
# %%bash
# rm -R tensorflow-for-poets-2
# rm *.pyc
# git clone https://github.com/googlecodelabs/tensorflow-for-poets-2
#
# pwd
# ls
# Out:
# Cloning into 'tensorflow-for-poets-2'...
# /gpfs/fs01/user/s37a-6a8375ad9b78b5-6459f7095f24/notebook/work
# ~
# cars.csv
# cifar_cnn.py
# color_scatter.html
# datasets
# displayImage.py
# DSX_Population
# ex_retrain
# file.csv
# images
# __init__.py
# layers.py
# my_model.pkl
# rose-2.jpg
# tensorflow-for-poets-2
# test_image.png
# tmp
# WA_Fn-UseC_-Telco-Customer-Churn.csv
# rm: cannot remove ‘*.pyc’: No such file or directory

# %% [markdown]
# # 2) Download the Training Images
# Before you start any training, you'll need a set of images to teach the model about the new classes you want to recognize. codelabs.developers.google.com created an archive of creative-commons licensed flower photos to use initially. To save time, **Just run this cell once** ,we only need to download the files once! Download the photos (218 MB) by invoking the following two commands:

# %%
# %%bash
# cd tensorflow-for-poets-2/tf_files/
# pwd
# ls
# Out:
# /gpfs/fs01/user/s37a-6a8375ad9b78b5-6459f7095f24/notebook/work/tensorflow-for-poets-2/tf_files

# %%
# %%bash
# cd tensorflow-for-poets-2/
# rm -R GoingBananasTransferLearning
# git clone https://github.com/zmadscientist/GoingBananasTransferLearning.git
# cd GoingBananasTransferLearning
# tar -zxf bananas.tgz
# cd bananas
# mv TestBananas ..
# pwd
# ls
# Out:
# Cloning into 'GoingBananasTransferLearning'...
# /gpfs/fs01/user/s37a-6a8375ad9b78b5-6459f7095f24/notebook/work/tensorflow-for-poets-2/GoingBananasTransferLearning/bananas
# bananablack
# bananagreen
# bananaoverripe
# bananaripe
# bananayellow
# rm: cannot remove ‘GoingBananasTransferLearning’: No such file or directory

# %% [markdown]
# Had you wished to experiment with something other than flowers, you could take the folloing steps (let's assume you want to classify star wars characters from the internet) :
# * cd tensorflow-for-poets-2/tf_files/
# * mkdir starwars
# * cd starwars
# * mkdir darth
# * mkdir leia
# * mkdir C3PO
# * Follow these steps by Siraj Raval on Youtube to bulk download 200 images for each starwars character
#
# Youtube (Siraj Raval): Build a TensorFlow Image Classifier in 5 Min
# Then classify the iamges in the same way we do for flowers below, replacing 'starwars' for 'flower_photos'
#
# You should now have a copy of the flower photos in your working directory. The fodler represent the labels we are going to predict. Confirm the contents of your working directory by issuing the following command:

# %%
# %%bash
# cd tensorflow-for-poets-2/GoingBananasTransferLearning/bananas/
# pwd
# ls
# Out:
# /gpfs/fs01/user/s37a-6a8375ad9b78b5-6459f7095f24/notebook/work/tensorflow-for-poets-2/GoingBananasTransferLearning/bananas
# bananablack
# bananagreen
# bananaoverripe
# bananaripe
# bananayellow

# %% [markdown]
# # 3) Start TensorBoard (Optional not working yet)
# Before starting the training, launch tensorboard in the background. TensorBoard is a monitoring and inspection tool included with tensorflow. You will use it to monitor the training progress.

# %%
# %%bash
# #cd tensorflow-for-poets-2
# #tensorboard --logdir tf_files/training_summaries &

# %% [markdown]
# ### In Case of Tensorboard error

# %% [markdown]
# This command above will fail with the following error if you already have a tensorboard process running:
#
# **ERROR:tensorflow:TensorBoard attempted to bind to port 6006**, but it was already in use
#
# You can kill all existing TensorBoard instances with:
#
# **!pkill -f "tensorboard"**

# %%
# %%bash
# wget http://ipinfo.io/ip -qO -
# #pkill -f "tensorboard"
# cd tensorflow-for-poets-2
# pwd
# ls
# Out:
# 169.55.224.149
# /gpfs/fs01/user/s37a-6a8375ad9b78b5-6459f7095f24/notebook/work/tensorflow-for-poets-2
# android
# CONTRIBUTING.md
# LICENSE
# README.md
# Screenshot.png
# scripts
# tf_files

# %% [markdown]
# # 4) Configure your MobileNet & Run the Training
# The retrain script can retrain either **Inception V3** model or a **MobileNet**. In this exercise, we will use a MobileNet. The principal difference is that Inception V3 is optimized for accuracy, while the MobileNets are optimized to be small and efficient, at the cost of some accuracy.
#
# ### What are we trying to accomplish here?
# We are taking a pretrained model that does at good job at some recognition tasks. But it has not been trained to distinguish particular items such as types of flowers. We are leveraging a technique called **transfer learning** that allows us to take advantage of the lions share of the work involved in training a model on images. The script we are using removes that very last layer of the Inception model - the one that know s how to classify 1000 general purpose images - and it adds a new layer that will be trained instead on the our handful of flower folders.
#
# #### Note:
# The original Inception model had never seen or been trained initailly for classify flowers. We will do that now.
#
# ### Patience
# This transfer learning training step may take up to two minutes

# %%
# %%bash
# cd tensorflow-for-poets-2
# export IMAGE_SIZE=224
# export ARCHITECTURE="mobilenet_0.50_${IMAGE_SIZE}"
#
# echo ${IMAGE_SIZE}
# echo ${ARCHITECTURE}
# start=`date +%s`
# python -m scripts.retrain \
#   --bottleneck_dir=tf_files/bottlenecks \
#   --how_many_training_steps=500 \
#   --model_dir=tf_files/models/ \
#   --summaries_dir=tf_files/training_summaries/"${ARCHITECTURE}" \
#   --output_graph=tf_files/retrained_graph.pb \
#   --output_labels=tf_files/retrained_labels.txt \
#   --architecture="${ARCHITECTURE}" \
#   --image_dir=GoingBananasTransferLearning/bananas/
#
# end=`date +%s`
# runtime=$((end-start))
# echo $runtime seconds
# Out:
# 224
# mobilenet_0.50_224
# >> Downloading mobilenet_v1_0.50_224_frozen.tgz 100.1%
# Converted 2 variables to const ops.
# 34 seconds
# Traceback (most recent call last):
#   File "/usr/local/src/bluemix_jupyter_bundle.v63/notebook/lib/python2.7/logging/__init__.py", line 853, in emit
#     msg = self.format(record)
#   File "/usr/local/src/bluemix_jupyter_bundle.v63/notebook/lib/python2.7/logging/__init__.py", line 726, in format
#     return fmt.format(record)
#   File "/usr/local/src/bluemix_jupyter_bundle.v63/notebook/lib/python2.7/logging/__init__.py", line 465, in format
#     record.message = record.getMessage()
#   File "/usr/local/src/bluemix_jupyter_bundle.v63/notebook/lib/python2.7/logging/__init__.py", line 329, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Logged from file tf_logging.py, line 82
# INFO:tensorflow:Looking for images in 'bananagreen'
# INFO:tensorflow:Looking for images in 'bananayellow'
# INFO:tensorflow:Looking for images in 'bananaripe'
# INFO:tensorflow:Looking for images in 'bananaoverripe'
# INFO:tensorflow:Looking for images in 'bananablack'
# 2017-10-09 15:37:46.401375: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-09 15:37:46.401398: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-09 15:37:46.401405: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-09 15:37:46.401411: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-09 15:37:46.401416: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR3.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR17.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR18.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR6.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR9.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR2.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR5.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR8.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR4.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR10.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR12.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR14.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR15.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR21.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR16.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR7.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR11.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR13.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR19.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR1.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR20.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananaoverripe/OR22.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G34.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G13.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G58.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G51.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G16.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G54.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G7.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G19.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G33.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G5.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G36.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G8.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G50.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G28.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G42.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G39.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G53.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G21.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G18.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G45.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G1.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G56.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G24.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G48.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G59.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G27.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G41.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G20.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G44.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G15.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G40.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G6.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G9.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G32.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G29.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/G43.jpg_mobilenet_0.50_224.txt
# INFO:tensorflow:Creating bottleneck at tf_files/bottlenecks/bananagreen/
0% (N=100)
# INFO:tensorflow:2017-10-09 15:38:12.004397: Step 400: Train accuracy = 100.0%
# INFO:tensorflow:2017-10-09 15:38:12.004556: Step 400: Cross entropy = 0.007824
# INFO:tensorflow:2017-10-09 15:38:12.044993: Step 400: Validation accuracy = 69.0% (N=100)
# INFO:tensorflow:2017-10-09 15:38:12.472163: Step 410: Train accuracy = 100.0%
# INFO:tensorflow:2017-10-09 15:38:12.472379: Step 410: Cross entropy = 0.004661
# INFO:tensorflow:2017-10-09 15:38:12.512927: Step 410: Validation accuracy = 64.0% (N=100)
# INFO:tensorflow:2017-10-09 15:38:12.937364: Step 420: Train accuracy = 100.0%
# INFO:tensorflow:2017-10-09 15:38:12.937534: Step 420: Cross entropy = 0.005915
# INFO:tensorflow:2017-10-09 15:38:12.978178: Step 420: Validation accuracy = 71.0% (N=100)
# INFO:tensorflow:2017-10-09 15:38:13.404441: Step 430: Train accuracy = 100.0%
# INFO:tensorflow:2017-10-09 15:38:13.404611: Step 430: Cross entropy = 0.005207
# INFO:tensorflow:2017-10-09 15:38:13.445085: Step 430: Validation accuracy = 66.0% (N=100)
# INFO:tensorflow:2017-10-09 15:38:13.866192: Step 440: Train accuracy = 100.0%
# INFO:tensorflow:2017-10-09 15:38:13.866349: Step 440: Cross entropy = 0.006806
# INFO:tensorflow:2017-10-09 15:38:13.910652: Step 440: Validation accuracy = 66.0% (N=100)
# INFO:tensorflow:2017-10-09 15:38:14.359575: Step 450: Train accuracy = 100.0%
# INFO:tensorflow:2017-10-09 15:38:14.359753: Step 450: Cross entropy = 0.005944
# INFO:tensorflow:2017-10-09 15:38:14.401068: Step 450: Validation accuracy = 63.0% (N=100)
# INFO:tensorflow:2017-10-09 15:38:14.856174: Step 460: Train accuracy = 100.0%
# INFO:tensorflow:2017-10-09 15:38:14.856339: Step 460: Cross entropy = 0.005783
# INFO:tensorflow:2017-10-09 15:38:14.899348: Step 460: Validation accuracy = 68.0% (N=100)
# INFO:tensorflow:2017-10-09 15:38:15.360756: Step 470: Train accuracy = 100.0%
# INFO:tensorflow:2017-10-09 15:38:15.360953: Step 470: Cross entropy = 0.006337
# INFO:tensorflow:2017-10-09 15:38:15.401852: Step 470: Validation accuracy = 70.0% (N=100)
# INFO:tensorflow:2017-10-09 15:38:15.829352: Step 480: Train accuracy = 100.0%
# INFO:tensorflow:2017-10-09 15:38:15.829543: Step 480: Cross entropy = 0.004372
# INFO:tensorflow:2017-10-09 15:38:15.870114: Step 480: Validation accuracy = 62.0% (N=100)
# INFO:tensorflow:2017-10-09 15:38:16.298617: Step 490: Train accuracy = 100.0%
# INFO:tensorflow:2017-10-09 15:38:16.298775: Step 490: Cross entropy = 0.006046
# INFO:tensorflow:2017-10-09 15:38:16.339036: Step 490: Validation accuracy = 60.0% (N=100)
# INFO:tensorflow:2017-10-09 15:38:16.722453: Step 499: Train accuracy = 100.0%
# INFO:tensorflow:2017-10-09 15:38:16.722619: Step 499: Cross entropy = 0.004653
# INFO:tensorflow:2017-10-09 15:38:16.763314: Step 499: Validation accuracy = 65.0% (N=100)
# INFO:tensorflow:Final test accuracy = 81.5% (N=27)
# INFO:tensorflow:Froze 2 variables.

# %% [markdown]
# # 5) Test an image to see how well it classifies
# try a daisy from here: tf_files/flower_photos/daisy/21652746_cc379e0eea_m.jpg

# %%
# %%bash
# ls tensorflow-for-poets-2/GoingBananasTransferLearning/TestBananas/
# Out:
# 08_suprising_uses_banana_compost_pile_ChiccoDodiFC.jpg
# 45767418_apbananas.jpg
# baked-bananas.jpg
# bananas-1642706_960_720.jpg
# bananas-for-Baki.jpg
# Cavendish-Bananas.jpg
# dsc07101.jpg
# greenbananas.jpg
# Growing.jpg
# How-to-Add-More-Bananas-To-Your-Diet.jpg
# images.jfif
# ripe.jpg
# ripened-bananas.jpg
# stock-photo-over-ripe-banana-isolated-on-white-with-clipping-path-113599891.jpg
# Thumbs.db

# %%
from displayImage import displayImage
displayImage('./tensorflow-for-poets-2/GoingBananasTransferLearning/TestBananas/stock-photo-over-ripe-banana-isolated-on-white-with-clipping-path-113599891.jpg')

# %%
# %%bash
# cd tensorflow-for-poets-2
# python -m scripts.label_image \
#     --graph=tf_files/retrained_graph.pb  \
#     --image=GoingBananasTransferLearning/TestBananas/stock-photo-over-ripe-banana-isolated-on-white-with-clipping-path-113599891.jpg
# Out:
# bananaoverripe 0.644065
# bananaripe 0.35166
# bananablack 0.00422835
# bananagreen 4.34925e-05
# bananayellow 3.18995e-06
# 2017-10-09 15:43:58.691085: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-09 15:43:58.691115: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-09 15:43:58.691122: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-09 15:43:58.691127: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-10-09 15:43:58.691133: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.

# %% [markdown]
# # 6) Download a jpg Flower Image from the Internet
# try finding a rose jpg on the internet
# wget the file to the flower_photos folder

# %%
# %%bash
# cd ~/notebook/work/tensorflow-for-poets-2/tf_files/flower_photos/
# wget http://laphiloselonsylvie2.a.l.f.unblog.fr/files/2014/07/rose-2.jpg
# pwd
# ls
# Out:
# /gpfs/fs01/user/s37a-6a8375ad9b78b5-6459f7095f24/notebook/work/tensorflow-for-poets-2/tf_files/flower_photos
# daisy
# dandelion
# LICENSE.txt
# rose-2.jpg
# roses
# sunflowers
# tulips
# --2017-10-02 18:15:38--  http://laphiloselonsylvie2.a.l.f.unblog.fr/files/2014/07/rose-2.jpg
# Resolving laphiloselonsylvie2.a.l.f.unblog.fr (laphiloselonsylvie2.a.l.f.unblog.fr)... 178.33.42.85
# Connecting to laphiloselonsylvie2.a.l.f.unblog.fr (laphiloselonsylvie2.a.l.f.unblog.fr)|178.33.42.85|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 137043 (134K) [image/jpeg]
# Saving to: ‘rose-2.jpg’
#
#      0K .......... .......... .......... .......... .......... 37%  228K 0s
#     50K .......... .......... .......... .......... .......... 74%  453K 0s
#    100K .......... .......... .......... ...                  100%  307K=0.4s
#
# 2017-10-02 18:15:39 (304 KB/s) - ‘rose-2.jpg’ saved [137043/137043]

# %%
# !pwd
# !ls
# Out:
# /gpfs/fs01/user/s37a-6a8375ad9b78b5-6459f7095f24/notebook/work
# ~		 DSX_Population  layers.py		 test_image.png
# cifar_cnn.py	 ex_retrain	 my_model.pkl		 tmp
# datasets	 images		 rose-2.jpg
# displayImage.py  __init__.py	 tensorflow-for-poets-2

# %%
from displayImage import displayImage
displayImage('./tensorflow-for-poets-2/tf_files/flower_photos/rose-2.jpg')

# %% [markdown]
# # 7) Test the web image we downloaded
# look in the
# * **~/notebook/work/tensorflow-for-poets-2/tf_files/flower_photos/**
#
# folder
#
# For example, we downloaded an internet image called rose-2.jpg

# %%
# %%bash
# cd tensorflow-for-poets-2
# python -m scripts.label_image \
#     --graph=tf_files/retrained_graph.pb  \
#     --image=../rose-2.jpg                                                                                                                                                                                                      2> errorlog.txt
# Out:
# roses 0.950057
# tulips 0.0498037
# sunflowers 9.18607e-05
# dandelion 2.52226e-05
# daisy 2.21806e-05

# %% [markdown]
# # Conclusion
# We downloaded a model from github.com/googlecodelabs/ that is trained for general images. It is not trained to classify the flower types we had in mind. We retrained the model with a realtively small number of jpgs for each new class. The way the images were labeled in this example was by the folder name for each class.
#
# The retrain script identifies the names and locations of out labeled classs via the folder names, and then freezes the lower detaield layers of the model, adds a new layer to reflect the number of new classes we care about, and retrains the model.
#
# We then tested the model by downloading an image from the internet related to one of our newly trained classes, and observed that the random image was classified pretty accurately.
